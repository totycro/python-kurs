# %%
import pandas as pd
df = pd.read_excel("../2019-2020/praxisbeispiel/Produktionsdaten.xlsx")
df
# Out:
#      Binder Nr.  Lamellenbreite - Fertigmaß [mm]  Temperatur [°C]  \
# 0           1.0                            140.0             19.1
# 1           2.0                            140.0             19.1
# 2           3.0                            140.0             19.1
# 3           4.0                            140.0             19.1
# 4           5.0                            140.0             19.1
# ..          ...                              ...              ...
# 511         NaN                              NaN              NaN
# 512         NaN                              NaN              NaN
# 513         NaN                              NaN              NaN
# 514         NaN                              NaN              NaN
# 515         NaN                              NaN              NaN
#
#      rel. Luftfeuchtigkeit [%]  Hobelmaß Lamellenhobel Breitseite [mm]  \
# 0                         74.0                                     1.5
# ...

# %%
df = df[df['Binder Nr.'].notna()]

# %%
df
# Out:
#      Binder Nr.  Lamellenbreite - Fertigmaß [mm]  Temperatur [°C]  \
# 0           1.0                            140.0             19.1
# 1           2.0                            140.0             19.1
# 2           3.0                            140.0             19.1
# 3           4.0                            140.0             19.1
# 4           5.0                            140.0             19.1
# ..          ...                              ...              ...
# 456       457.0                            140.0             20.2
# 457       458.0                            140.0             20.2
# 458       459.0                            140.0             20.2
# 459       460.0                            140.0             20.2
# 460       461.0                            140.0             20.2
#
#      rel. Luftfeuchtigkeit [%]  Hobelmaß Lamellenhobel Breitseite [mm]  \
# 0                         74.0                                     1.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 461 entries, 0 to 460
# Data columns (total 20 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Binder Nr.                              461 non-null    float64
#  1   Lamellenbreite - Fertigmaß [mm]         461 non-null    float64
#  2   Temperatur [°C]                         461 non-null    float64
#  3   rel. Luftfeuchtigkeit [%]               461 non-null    float64
#  4   Hobelmaß Lamellenhobel Breitseite [mm]  461 non-null    float64
#  5   Scanparameter Röntgen                   461 non-null    float64
#  6   Scanparameter Laser                     461 non-null    float64
#  7   Scanparameter Farbkamera                461 non-null    float64
#  8   Hobelmaß Keilzinkung Breitseite [mm]    461 non-null    float64
#  9   Hobelmaß Keilzinkung Schmalseite [mm]   461 non-null    float64
# ...

# %%
df['Temperatur [°C]'].plot()
# Out:
# <AxesSubplot:>

# %%
df['Temperatur [°C]'].hist()
# Out:
# <AxesSubplot:>

# %%
df[ ['Ausbeute nach Fehlerkappung [%]', 'rel. Luftfeuchtigkeit [%]'] ].plot()
# Out:
# <AxesSubplot:>

# %%
df['Ausbeute nach Fehlerkappung [%]'].corr(df['rel. Luftfeuchtigkeit [%]'])
# Out:
# 0.040686703652702494
